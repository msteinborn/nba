# %%
from nba_api.stats.endpoints import playercareerstats
# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id='203076')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2012-13        00  1610612740               NOH        20.0
# 1     203076   2013-14        00  1610612740               NOP        21.0
# 2     203076   2014-15        00  1610612740               NOP        22.0
# 3     203076   2015-16        00  1610612740               NOP        23.0
# 4     203076   2016-17        00  1610612740               NOP        24.0
# 5     203076   2017-18        00  1610612740               NOP        25.0
# 6     203076   2018-19        00  1610612740               NOP        26.0
# 7     203076   2019-20        00  1610612747               LAL        26.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  64  60  1846.0  349  ...   0.751   165   357  522   63   75  112   89  158
# 1  67  66  2358.0  522  ...   0.791   207   466  673  105   89  189  109  200
# 2  68  68  2455.0  642  ...   0.805   173   523  696  149  100  200   95  141
# 3  61  61  2164.0  560  ...   0.758   130   497  627  116   78  125  121  148
# 4  75  75  2708.0  770  ...   0.802   172   712  884  157   94  167  181  168
# 5  75  75  2727.0  780  ...   0.828   187   644  831  174  115  193  162  159
# 6  56  56  1850.0  530  ...   0.794   174   498  672  218   88  135  112  132
# 7   3   3   102.0   25  ...   0.815     5    25   30   10    4   10   11   10
#
#     PTS
# 0   867
# 1  1394
# 2  1656
# 3  1481
# 4  2099
# 5  2110
# 6  1452
# 7    75
#
# [8 rows x 27 columns]

# %%
from nba_api.stats.static import teams

nba_teams = teams.get_teams()
# Select the dictionary for the Celtics, which contains their team ID
celtics = [team for team in nba_teams if team['abbreviation'] == 'BOS'][0]
celtics_id = celtics['id']

knicks = [team for team in nba_teams if team['abbreviation'] == 'NYK'][0]
knicks_id = knicks['id']

# %%
from nba_api.stats.endpoints import leaguegamefinder
import matplotlib.pyplot as plt

# Query for games where the Celtics were playing
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id, vs_team_id_nullable = knicks_id)
# The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0     22019  1610612738               BOS  Boston Celtics  0021900029
# 1     22018  1610612738               BOS  Boston Celtics  0021800771
# 2     22018  1610612738               BOS  Boston Celtics  0021800365
# 3     22018  1610612738               BOS  Boston Celtics  0021800255
# 4     22018  1610612738               BOS  Boston Celtics  0021800028
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2019-10-26    BOS @ NYK  W  242  118  ...   0.655    13    33   46   24
# 1  2019-02-01    BOS @ NYK  W  241  113  ...   0.800    11    32   43   25
# 2  2018-12-06  BOS vs. NYK  W  240  128  ...   0.850     7    39   46   32
# 3  2018-11-21  BOS vs. NYK  L  241  109  ...   0.719    15    35   50   30
# 4  2018-10-20    BOS @ NYK  W  240  103  ...   0.848    11    36   47   21
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0   14    9   12  26        23.0
# 1   11    7    7  18        14.0
# 2    8    6    9  24        28.0
# 3   10    9    8  16        -8.0
# 4    8    2   15  26         2.0
#
# [5 rows x 28 columns]

# %%
games.groupby(games.SEASON_ID.str[-4:])[['GAME_ID']].count().loc['2015':]
# Out:
#            GAME_ID
# SEASON_ID
# 2015             6
# 2016             6
# 2017             4
# 2018             5
# 2019             1

# %%
lastknicksgame = games.sort_values('GAME_DATE').iloc[-10:]
lastknicksgame.head(n=10)
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 9     22017  1610612738               BOS  Boston Celtics  0021700051
# 8     22017  1610612738               BOS  Boston Celtics  0021700468
# 7     22017  1610612738               BOS  Boston Celtics  0021700758
# 6     22017  1610612738               BOS  Boston Celtics  0021700886
# 5     22018  1610612738               BOS  Boston Celtics  1521800055
# 4     22018  1610612738               BOS  Boston Celtics  0021800028
# 3     22018  1610612738               BOS  Boston Celtics  0021800255
# 2     22018  1610612738               BOS  Boston Celtics  0021800365
# 1     22018  1610612738               BOS  Boston Celtics  0021800771
# 0     22019  1610612738               BOS  Boston Celtics  0021900029
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 9  2017-10-24  BOS vs. NYK  W  241  110  ...   0.815     5    36   41   26
# 8  2017-12-21    BOS @ NYK  L  239   93  ...   0.737     9    26   35   17
# 7  2018-01-31  BOS vs. NYK  W  240  103  ...   0.600     5    44   49   27
# 6  2018-02-24    BOS @ NYK  W  240  121  ...   0.857    11    34   45   21
# 5  2018-07-12  BOS vs. NYK  W  201   82  ...   0.750    14    27   41   17
# 4  2018-10-20    BOS @ NYK  W  240  103  ...   0.848    11    36   47   21
# 3  2018-11-21  BOS vs. NYK  L  241  109  ...   0.719    15    35   50   30
# 2  2018-12-06  BOS vs. NYK  W  240  128  ...   0.850     7    39   46   32
# 1  2019-02-01    BOS @ NYK  W  241  113  ...   0.800    11    32   43   25
# 0  2019-10-26    BOS @ NYK  W  242  118  ...   0.655    13    33   46   24
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 9   11    7   12  24        21.0
# 8   11    1   10  20        -8.8
# 7    8    3    9  22        30.0
# 6   11    5   11  15         9.0
# 5    7    6    7  19        12.0
# 4    8    2   15  26         2.0
# 3   10    9    8  16        -8.0
# 2    8    6    9  24        28.0
# 1   11    7    7  18        14.0
# 0   14    9   12  26        23.0
#
# [10 rows x 28 columns]

# %%
avg_pm = 0
pm = []

for i in range( 0, len(lastknicksgame.PLUS_MINUS)):
        avg_pm = (avg_pm + lastknicksgame.PLUS_MINUS[i])/(i+1)
        pm.append(avg_pm)
plt.scatter(y =pm, x= range(0, len(pm)))
plt.show()

# %%
lastknicksgame = games.sort_values('GAME_DATE').iloc[-1]
lastknicksgame.head()
# Out:
# SEASON_ID                     22019
# TEAM_ID                  1610612738
# TEAM_ABBREVIATION               BOS
# TEAM_NAME            Boston Celtics
# GAME_ID                  0021900029
# Name: 0, dtype: object

# %%
from nba_api.stats.endpoints import playbyplayv2
import pandas as pd

description = []

pbp = playbyplayv2.PlayByPlayV2(lastknicksgame.GAME_ID)
pbp = pbp.get_data_frames()[0]
pbp.head(n = 10)

for i in range(0, len(pbp.GAME_ID)):
    if pbp.PLAYER1_TEAM_NICKNAME[i] == 'Celtics' or pbp.PLAYER2_TEAM_NICKNAME[i] == 'Celtics' or pbp.PLAYER3_TEAM_NICKNAME[i] == 'Celtics':
        if pbp.HOMEDESCRIPTION[i] != None:
            description.append(pbp.HOMEDESCRIPTION[i])
        else:
            description.append(pbp.VISITORDESCRIPTION[i])

description
# Out:
# ['Jump Ball Robinson vs. Williams III: Tip to Walker',
#  None,
#  'Payton STEAL (1 STL)',
#  None,
#  'Morris Sr. P.FOUL (P1.T1) (N.Sago)',
#  None,
#  'Randle Bad Pass Turnover (P1.T1)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Barrett Bad Pass Turnover (P1.T3)',
#  None,
#  None,
#  'Robinson P.FOUL (P1.T2) (N.Sago)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Payton STEAL (2 STL)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  "MISS Barrett 2' Driving Layup",
#  None,
#  None,
#  None,
#  'Portis OFF.Foul (P1) (E.Lewis)',
#  None,
#  None,
#  None,
#  'Randle Lost Ball Turnover (P2.T7)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Portis S.FOUL (P2.T3) (D.Collins)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Trier Bad Pass Turnover (P1.T9)',
#  'Trier C.P.FOUL (P1.T1) (D.Collins)',
#  None,
#  None,
#  None,
#  'Trier P.FOUL (P2.T2) (D.Collins)',
#  None,
#  'Smith Jr. Bad Pass Turnover (P2.T11)',
#  'Smith Jr. S.FOUL (P1.T3) (E.Lewis)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Smith Jr. P.FOUL (P2.T4) (D.Collins)',
#  'Smith Jr. STEAL (1 STL)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Morris Sr. OFF.Foul (P2) (N.Sago)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Robinson S.FOUL (P2.PN) (N.Sago)',
#  None,
#  "MISS Payton 7' Turnaround Hook Shot",
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Payton Bad Pass Turnover (P2.T13)',
#  None,
#  "MISS Barrett 2' Driving Dunk",
#  None,
#  None,
#  None,
#  None,
#  'Robinson BLOCK (1 BLK)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Robinson P.FOUL (P3.PN) (E.Lewis)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  "MISS Barrett 1' Driving Reverse Layup",
#  None,
#  None,
#  None,
#  "MISS Randle 2' Layup",
#  None,
#  None,
#  'Payton STEAL (3 STL)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Payton Offensive Charge Foul (P1.PN) (N.Sago)',
#  None,
#  'Morris Sr. Bad Pass Turnover (P2.T15)',
#  None,
#  'Randle Bad Pass Turnover (P3.T16)',
#  'Barrett S.FOUL (P1.T1) (N.Sago)',
#  None,
#  None,
#  None,
#  None,
#  'Robinson S.FOUL (P4.T2) (E.Lewis)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Morris Sr. Lost Ball Turnover (P3.T17)',
#  None,
#  None,
#  None,
#  'Portis P.FOUL (P3.T3) (E.Lewis)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Randle STEAL (1 STL)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Portis Bad Pass Turnover (P2.T18)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Morris Sr. STEAL (1 STL)',
#  None,
#  None,
#  None,
#  'Barrett S.FOUL (P2.T4) (E.Lewis)',
#  None,
#  None,
#  "MISS Barrett 2' Putback Layup",
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Morris Sr. S.FOUL (P3.PN) (E.Lewis)',
#  None,
#  'Barrett Bad Pass Turnover (P3.T19)',
#  'Payton STEAL (4 STL)',
#  'Portis S.FOUL (P4.PN) (E.Lewis)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Smith Jr. S.FOUL (P3.PN) (N.Sago)',
#  None,
#  None,
#  None,
#  'Portis BLOCK (1 BLK)',
#  None,
#  None,
#  'Barrett S.FOUL (P3.PN) (N.Sago)',
#  None,
#  "MISS Portis 2' Layup",
#  None,
#  None,
#  None,
#  'Trier P.FOUL (P3.PN) (N.Sago)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Knox II Lost Ball Turnover (P1.T21)',
#  'Knox II P.FOUL (P1.T1) (E.Lewis)',
#  None,
#  None,
#  'Robinson BLOCK (2 BLK)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Robinson BLOCK (3 BLK)',
#  None,
#  None,
#  'Payton L.B.FOUL (P2.T2) (N.Sago)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Morris Sr. S.FOUL (P4.T3) (E.Lewis)',
#  None,
#  "MISS Randle 3' Layup",
#  None,
#  None,
#  "MISS Payton 15' Fadeaway Jumper",
#  None,
#  None,
#  None,
#  None,
#  'Randle Lost Ball Turnover (P4.T23)',
#  None,
#  None,
#  None,
#  'Barrett Lost Ball Turnover (P4.T24)',
#  'Randle S.FOUL (P1.T4) (D.Collins)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Portis S.FOUL (P5.PN) (E.Lewis)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
