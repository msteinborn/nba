# %%
from nba_api.stats.endpoints import playergamelog

games = playergamelog.PlayerGameLog(player_id='1628369')
games = games.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     22019    1628369  0021900029  OCT 26, 2019    BOS @ NYK  W   34    5
# 1     22019    1628369  0021900017  OCT 25, 2019  BOS vs. TOR  W   35    8
# 2     22019    1628369  0021900008  OCT 23, 2019    BOS @ PHI  L   37    8
#
#    FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   17   0.294  ...     7    9    0    3    2    2   3   15          20
# 1   22   0.364  ...     6    9    4    3    0    0   0   25           9
# 2   22   0.364  ...     9   10    2    2    0    4   2   21          -4
#
#    VIDEO_AVAILABLE
# 0                1
# 1                1
# 2                1
#
# [3 rows x 27 columns]

# %%
from nba_api.stats.endpoints import playbyplayv2

newest_game = games.Game_ID[1]

pbp = playbyplayv2.PlayByPlayV2(newest_game)
pbp = pbp.get_data_frames()[0]
pbp.head()
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0  0021900017         2            12                   0       1
# 1  0021900017         4            10                   0       1
# 2  0021900017         8             2                 101       1
# 3  0021900017         9             4                   0       1
# 4  0021900017        10             2                 101       1
#
#   WCTIMESTRING PCTIMESTRING                             HOMEDESCRIPTION  \
# 0      7:11 PM        12:00                                        None
# 1      7:11 PM        12:00  Jump Ball Theis vs. Gasol: Tip to VanVleet
# 2      7:11 PM        11:46                                        None
# 3      7:11 PM        11:44                 Theis REBOUND (Off:0 Def:1)
# 4      7:12 PM        11:31    MISS Theis 4' Driving Floating Jump Shot
#
#   NEUTRALDESCRIPTION                          VISITORDESCRIPTION  ...  \
# ...

# %%
tatumpbp = pbp.loc[pbp['PLAYER1_ID'] == 1628369]
tatumpbp.head()
# Out:
#        GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 19  0021900017        29             2                  63       1
# 48  0021900017        63             4                   0       1
# 49  0021900017        64             2                 101       1
# 50  0021900017        65             4                   0       1
# 57  0021900017        73             8                   0       1
#
#    WCTIMESTRING PCTIMESTRING                            HOMEDESCRIPTION  \
# 19      7:14 PM         9:44             MISS Tatum 14' Fadeaway Jumper
# 48      7:18 PM         7:29                Tatum REBOUND (Off:0 Def:1)
# 49      7:18 PM         7:19  MISS Tatum 17' Driving Floating Jump Shot
# 50      7:18 PM         7:18                Tatum REBOUND (Off:1 Def:1)
# 57      7:21 PM         6:45                       SUB: Smart FOR Tatum
#
#    NEUTRALDESCRIPTION VISITORDESCRIPTION  ... PLAYER2_TEAM_NICKNAME  \
# ...

# %%
tatummake = tatumpbp.loc[tatumpbp['EVENTMSGTYPE'] == 1]
tatummake
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 104  0021900017       141             1                  78       1
# 110  0021900017       149             1                   1       1
# 130  0021900017       180             1                 108       2
# 181  0021900017       254             1                   6       2
# 318  0021900017       455             1                   6       3
# 336  0021900017       478             1                   1       3
# 353  0021900017       501             1                   1       3
# 441  0021900017       630             1                   1       4
#
#     WCTIMESTRING PCTIMESTRING  \
# 104      7:34 PM         2:26
# 110      7:35 PM         1:27
# 130      7:40 PM        11:46
# 181      7:51 PM         7:21
# 318      8:39 PM         4:39
# 336      8:42 PM         3:23
# 353      8:48 PM         1:33
# 441      9:14 PM         4:33
#
# ...

# %%
import pandas as pd

raptor = pd.read_csv("modern_RAPTOR_by_player.csv")
raptor.head()

highwar = raptor.loc[raptor['war_total'] > 20 ]
highwar.head()
# Out:
#          player_name  player_id  season  poss    mp  raptor_box_offense  \
# 665    Stephen Curry  curryst01    2015  7192  3439            8.504968
# 666    Stephen Curry  curryst01    2016  7053  3314           10.532883
# 667    Stephen Curry  curryst01    2017  6963  3239            8.343958
# 1071  Draymond Green  greendr01    2016  7778  3687            2.645310
# 1130    James Harden  hardeja01    2018  6466  3172            9.390432
#
#       raptor_box_defense  raptor_box_total  raptor_onoff_offense  \
# 665             1.677165         10.182132              7.218913
# 666             1.688492         12.221375              7.781331
# 667            -0.273511          8.070447             11.207311
# 1071            4.760084          7.405394              8.459053
# 1130            1.451237         10.841669              3.936261
#
#       raptor_onoff_defense  ...  raptor_offense  raptor_defense  raptor_total  \
# ...

# %%
import matplotlib.pyplot as plt


raptor_plot = highwar.plot(kind="scatter", x = 'poss', y = 'predator_total')
for i, txt in enumerate(highwar["player_name"]):
    raptor_plot.annotate(txt, (x[i], y[i]))
